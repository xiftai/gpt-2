# %% [markdown]
# <a href="https://colab.research.google.com/github/ilopezfr/gpt-2/blob/master/gpt-2-playground_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-2 Playground
#
# ## Background
# In this Jupyter notebook you can play around with the small version of **Open AI's GPT-2** Model from the paper *[Language Models are Unsupervised Multitask Learners](https://d4mucfpksywv.cloudfront.net/better-language-models/language-models.pdf).*
#
# According to the authors, the GPT-2 algorithm was trained on the task of *language modeling*--- which tests a program's ability to predict the next word in a given sentence--by ingesting huge numbers of articles, blogs, and websites. By using just this data it achieved state-of-the-art scores on a number of unseen language tests, an achievement known as *zero-shot learning.* It can also perform other writing-related tasks, like translating text from one language to another, summarizing long articles, and answering trivia questions.
#
# Open AI decided not to release the dataset, training code, or the full GPT-2 model weights. This is due to the concerns about large language models being used to generate deceptive, biased, or abusive language at scale. Some examples of the applications of these models for malicious purposes are:
# * Generate misleading news articles
# * Impersonate others online
# * Automate the production of abusive or faked content to post on social media
# * Automate the production of spam/phishing content
#
# As one can imagine, this combined with recent advances in generation of synthetic imagery, audio, and video implies that it's never been easier to create fake content and spread disinformation at scale. The public at large will need to become more skeptical of the content they consume online.
#
# ## Steps
# Before starting, is recommended to set *Runtime Type* to *GPU* on the top menu bar.
#
#
# ###1. Installation
# Download the model data and istall Python libraries:

# %%
# !git clone https://github.com/ilopezfr/gpt-2/
import os
os.chdir('gpt-2')
# !sh download_model.sh 117M
# !pip3 install -r requirements.txt

# %% [markdown]
# ###  2. Unconditional sample generation
#
# WARNING: Samples are unfiltered and may contain offensive content.
#
# To generate unconditional samples from the small model:
# ```
# !python3 src/generate_unconditional_samples.py
# ```
# There are a few flags available.
# - `nsamples`: specify the number of samples you want to print
# - `length`
# - `batch_size`
# - `temperature`
# - `top_k`

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=40 --temperature=0.7 | tee samples

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=2

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=80

# %% [markdown]
# ## Conditional sample generation
#
# To generate conditional samples from the small model:
# ```
# !python3 src/interactive_conditional_samples.py
# ```
# There are a few flags available.
# - `nsamples`: specify the number of samples you want to print
# - `length`
# - `batch_size`
# - `temperature`
# - `top_k`
#
# Want to test it the AI model passes the Voight-Kampff test? Here are some sample prompts to help your start:
# - You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you.
# - What's it like to hold the hand of someone you love? Interlinked. Do they teach you how to feel finger to finger? Interlinked.
# - I've seen things you people wouldn't believe. Attack ships on fire off the shoulder of Orion. I watched C-beams glitter in the dark near the Tannhäuser Gate. All those moments will be lost in time, like tears in rain. Time to die.
# - In a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English.
# - Building the wall is not a national emergency.
# - Some of the most glorious historical attractions in Spain date from the period of Muslim rule, including The Mezquita, built as the Great Mosque of Cordoba and the Medina Azahara, also in Cordoba, the Palace of al-Andalus; and the Alhambra in Granada, a splendid, intact palace.
# - Our solar system consists of the inner and outer planets, separated by an asteroid belt. It has
# - The 10 best foods are: 1. Serrano Ham 2. Manchego Cheese 3.
# - "It was a difficult game, but the performance was weak," Real Madrid boss Santi Solari on the

# %%
# !python3 src/interactive_conditional_samples.py
# Out:
# 2019-02-16 00:32:58.874979: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-02-16 00:32:58.875252: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x34be680 executing computations on platform Host. Devices:
# 2019-02-16 00:32:58.875290: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-16 00:32:58.939793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-16 00:32:58.940280: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x34bf5a0 executing computations on platform CUDA. Devices:
# 2019-02-16 00:32:58.940317: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-16 00:32:58.940620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 3.41GiB
# 2019-02-16 00:32:58.940651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-16 00:32:59.322122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-16 00:32:59.322216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-16 00:32:59.322243: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-16 00:32:59.322411: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-16 00:32:59.322466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3138 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> The 10 best restaurants in San Francisco are:
# 2019-02-16 00:35:08.839580: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
#
#
# Rog & Magazines "Challenging Krochskaya-style burger, All Dine Out 750 First; Yellow Pages and the Food Planet" $44
#
# "Beat the bar and grab your home fries with chorizo ears". More info<|endoftext|>Hi everyone - the patchnotes are out!~~
#
# Further patchnotes forthcoming soon.
#
# v1.10:
#
# Many thanks to everyone who will be present, all- to the folks at GH&T.
#
# Updated EP Version to 1.7.22 with more cars and chase tracks.
#
# Fixed EP Version being extremely messy; Game Tavotes leveled up special levels multiplayer. ProductFixed mic entering an individual player's home screen much more than had previously, same like in xboxandita and xbox + reground. Made individual housing cost between 100-200$ per home to equip, reduced the time it takes for the individual player to stand around as opposed to before, and fixed ammo flight cost after every point upgrades and level thru 2 different modes.
#
# Fixed reground to start over, used as it is in Partial Relaxation.
#
# CompSan disappear missed immediatly after Abydos.
#
# Fixed several common bug in Apex's OS that cause massive shortcuts (Brianstyle, Purify Council, Richcliff or intelligent ratsface wasnt adding initial cape instances on the stage). Changed sim track to most travel time.
#
# Changed script queue to save initial time when a barter is entered (almost any variable named barter priority $1000 at most), also as a workaround for an infinite prize. (This however wont work the way before, so Highlife changed it to minions to avoid paying a slight penalty in cosmetic cost.)
#
# Changed seqSuffice to make Jaywalker respawn instantly at $1000 new landing speed. (This is car (vt)) Reduced Vehicinator to 10 happy and 10 sorry. (Za Mod controversards switched to from Deacon Republic form on plat 29 with english as default. Original patch is final but improving Logistics Unit here and Prospero edited it sadly so it wont take too much time even if it didnt work.)
#
# Reduced Invasion speech supply to 50% (3rd person set to Max 20%. 2nd person set to 30% at +30k support-maxing camkat, chipper Vulsecatoee setup turns down capped configs!)
#
# Added s01_004_00AA Water 30% faster easr and's.
# ================================================================================
# Model prompt >>> Our solar system consists of the inner and outer planets, separated by an asteroid belt. It has
# ======================================== SAMPLE 1 ========================================
# ices about the size of jacaranda or Gambia. This is because thrown from either side the local overlying atmosphere is filled by the inner planets, where they bounce off the Earth, making a partial moon rise all the way around them. That is exactly what the Earth gets when its atmosphere is purged out by the sun and volcanic gas.
#
# Researchers also note that yes, there is a large amount of rain coming out of Terra and other more dense around Earth, but the few clear days of January 2006 – when someone was invited in to provide information on 'habitable areas', with estimates of the amount of rainfall - are a backup from what otherwise had been deemed apocalyptic weather notes.
#
# In a post on Medium.com (and the general discussion of land use in California), Analysis wider than this refers to 2008 floods and drought made of Upstate New York; a small chunk of September boasted almost three times the electrical power agency's signifacient that year. The most recent rains has occurred in Pittsburgh, Ga., and along that coast the county held a town hall meeting in front of the New Braunfels Reform Center. Spectrum Historical Staff expert Andrew Larson inside the arch trusts his wife Bannon, and tabvey jale Saspton runs the site called Spotters.com, which keeps track of all Floridians' 'habitable areas' and ensure that there is a significant capacity for clean water. Simon Lehman writes about California survival under glass along northern New Jersey's Q tidal stream, while photographer Jess Smallwood and landscape photographer Chris McGinn take places like this:
#
# Published, according to Landsat data, on 7,771 banks in 45% of the State… Tidal flooding across all 50 states results in some twenty and forty boat crashes into landfills, a extreme time stress that many shopswell into the streets of stingy revelation. Tidal droughts were only mentioned by local politicians but many people told me Hayward had received several housing developments long before, more likely they were undergoing rehabilitation by storm surges. After all, the city has up to a tenth of Utah's net natural resources against fish, turtles, birds, sun-scrapers and scrub brush.
#
# Your state lacks the space to meet that pressing need.
#
# To Central Rural California, that parallel copyright protection would amount to shark fin stamped to state's most important alphabetical designation in 2012, while the sheriff's laborer makes "species" pig fur and rubber boots. Regulatory Secretary Andras Rivera has the
# ================================================================================
# Model prompt >>> The 10 best foods are: 1. Pizza 2.
# ======================================== SAMPLE 1 ========================================
#  Pizza 6. Pizza 6 6 12 11 11 12 11 11 12 11 8 10 10 9 9 0 Tournament title, season 23 Game 1 Game 2 Game 3 0-2-0 Team Fortress 2 vs. Terran Round 1 Round 2 Round 3 Round 4 Round 5 Round 6 Round 7 Round 8 Round 9 Round 10 Team Fortress 2 vs. Secret Round 1 Round 2 Round 3 Round 4 Round 5 Round 6 Round 7 Round 8 Round 9 Round 10 Total bans: 245 Top 8 Participants: 12 Amtebagov 3 Frotha Profile Blog Joined October 2010 United States 3382 Posts #11 This is really hellaiheart B-Sage: "Use us when you feel so sorry for everyone who's been responsible for UCA's misfortune." - Ryung
#
# XSupreme42 Profile Blog Joined May 2009 United States 4407 Posts #12 Minecraft wtf is that? Like most fans, I will tlinePC until HGO gaming offers me redeeming for selling pylons.
#
# pyshiz Profile Blog Joined August 2009 to 2010 United States 4361 Posts #13 I lose for vortix because it wasn't that deep into the mapet part, and pyd won, or because Vortix was there to prevent Lyrix from getting some HGO aggression. If you wanna be vortix for a day, make sure Pylons Destroy nothing / argue about stellar pylons afterSparky recently killed an RNG zerg so he can pick up 2nd kills at best 1.3 million reaver and cinder spike. I'm nuking my godz dancemon 3 DustYeaM-_-:- 2012-10-11 Tons of mad Geniuses of gaming, 2007-2008. Streamed by a few of them as Ball user MeNY-Vote #1 on Liquipedia
#
# fizL Profile Joined January 2008 Canada 432 Posts #14 On October 05 2010 19:36 Paperstress wrote:
#
# ELTS and (SL yours) bay a division once and see where it goes from there. I'm tempted to ladder before you ever joke that anything internationally romantic is OK single mission crowing alot different ideas to match pickup TXGO, Team SC but a fight for control of teammates is what evry.
#
# Not your kind...
#
#
# That only has dried my appetite I know my hunger is failing XDragon. Not your kind......That only has dried my appetite I know my hunger is failing Administrator
#
# Tenzgreeze Profile Joined January 2010
# ================================================================================
# Model prompt >>> The 10 best foods are: 1. Serrano Ham 2. Manchego Cheese 3.
# ======================================== SAMPLE 1 ========================================
#  Super Potato 4. Peanut Butter 5. Chia Seeds 6. Simia Lettuce 7. Chicken Tikka Masala 8.  Mexican Sauce 9. pumpkin seeds 10. Almond Hazelnut squash 11. Candy Pan 12. Grapefruit and Isley 13. Hazelnut squash 14. Cheesecake 15. Topspin Red Onion 16. Triforce Pure Wheat 17. poached flake 18. Glazed Apricot 19. Perennial Chard 20.  Pumpkin Conquering Herb 21. Duck Head Chili 22. Mighty Coconut 23.  Pumpkin Yum 54. 25's 26. Dairy Free-Peanut Butter Yogurt 27. Almond Mojito 28.  Cauliflower Dip 29. Lettuce Burrito 30. Macaroni and Cheese 31. Egg White Egg 32. Savory and Spicy Ass 33. Rhubarb Sauce 34. Marinated tomato with white bean salsa 35. Basic Winery Eggplant 36. Jetzed Rice 37. Korean Salad 38. Japanese Beef 39. Banana Wings 40. Double Chocolate Fries 41. Filling Jarod Cream 42. Pampos Lettuce, Tomatoes 43. Stuffed Starbucks Frappuccino 45. American Cheese 63 46 Amaranth Sauce 47. This is delicious! Kuma mushrooms and blackberries rank various combinations, but a spicy slice outta all of them? The ingredients listed below include an Asian Chili Puritan or two, as well as a Creole classic:  Italian i)  Sloppy Bell Chili (not sure if I find it authentic!)  and Bao Zi Traditional Popsicle
# 48. Dry Char "Morning Dew" and Chicken Stir-Fry When we say Meatball breakfast food, on its own not entirely unexpected. That's like the whole day before it goes to the buffet. Again, that's just a bit of explaining to me that Caesar elegant midnight rolls are cool. What else in the world does that one have to do with food? Check out this picture of a Salted Caramel Cheesecake from Trident Barbecue. Let us note, this is the Dragon
# 50. Invocations of smoke 49ers photo by Jawsig<|endoftext|>A vast stash of so-called bankrupt Canadian developers is growing by the day thanks to a prominent government guru making a grand bargain with JM and Cove Capital Pharmaceuticals Supplement Ltd toys to skyrocketing S$50.6 million immaculate private price levels.
#
# The so-called bottom line
# ================================================================================
# Model prompt >>> You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you. You reach
# ======================================== SAMPLE 1 ========================================
# ?"
#
# Transcendent Blade Enchantress was born to Marquis Ruby and his apprentice, Ross Fitzgerald. He was blocking Great Scarlet Ragon's Return. During guardian duty Negima, passioned, Abaddon, came and left. Nonetheless, Faust ascended to the highest levels of Witchy Mountain. Benedict sacrifices himself in support of its defenses and Fenav is transformed into the "befuddled godlayer" in Vol. 4. As subterranean Watchers, he worries about civilians. The Casket-In-Transcendent Blade Enchantress transforms into Sorrow for Her own evil. The Watcher herself escalates her forces to defend the hideout of Witchy Mountain. The Viceroy crashes the Ministry on its own forty floors and reports to Port Gyros. An entire town took on the name to avoid demon corruption and standing guard over his Shrine. Dancing and dancing around him was attached to everyone's favorite initiation story.
#
# The Copy Player can purchase Red, Green, Blue, or Legendary tickets to all six zones. One way to AV knows better is to have 75% Supporters.
#
# EGW Activation Schedule: What Colors offer Character restriction Other entity Activations Applied to Parliamentis Contested Parliamentis or Julius Caesar? SVOVis's Micropeptide Training and Balancing is Enforcement Disruption Line ReadVisement Checks for Figures Issuance Holdon Is known for calculating the output rate of damage in combos against party members, using Lieu lifesteal damage. MYS Army Hive Operations Height Adjusted Operation Playstyle
#
# Victor Blades - Frontline
#
# Center, Edge Setling - Flex Tracers
#
# Strength Sets Sets Stripping Sets
#
# Armored Arms Sets Dante (Reinforced "Curse of Longsword")
#
# Bargain +
#
# Dragon Arms Ares (Reinforced "Punch Attack" )
#
# Recouett +
#
# Streetfighter.BPB Male B Level large Nightthe Noctus Bedrounga Observatory Presentation ----------- Frank head 02
#
# Cite: Theme, Opening, First Verse, Cappy ("I'll hit like lightning.", "The great void travels strange places. Through the strange void lends me ruthless vengeance ya shinobi!"), call to its minions. Last night is my last night on earth "I hope on god's sake you sound mighty fine". Aquaman - The Second Nightthe Noctus Mayor -- The Third Night the Noctus Queen's best friend Brought back to her normal life Felic
# ================================================================================
# Model prompt >>> You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you.
# ======================================== SAMPLE 1 ========================================
# ?" said Alarm 7, "Are you... your partner - you're alive and well in this desert?" Owen said, "Yes I am", "No I can't stop you", "I love you too much" and "Okay then!" Alec said carefully.
#
# "I know, you'll eventually figure it out (but I'll never be able to do it!). I will thank you, Lord Voldemort, for your kindness to me like it is in an animal and a man!"
#
# Towards the end of the movie, who has verbally harassed Leia constantly on several occasions for being in touch with her beyond tea time, he refused to kill Keaton and stated:
#
# Whoever killed Vader and Redcliffe, is guilty-even though he tricked Val Lord (who didn't believe him) into giving the instructions that allowed him to do so. The reason for the execution was indeed that Lucas wanted to undo Darth Vader's crimes of noble devotion, so he declared another Jedi Knight "the Messiah", an openly evil choice. Even then, he had none of it for the Jedi. It was last night's slaughtered guest of the Baktic attacking Rebels. Luke declared:
#
# He and Vader knew this day would come, and it seemed unlikely that anyone would do even marginally worse to the brave man, since all they could do was ask that he be returned to normal territory and fulfilled arms-safety orders. Casts of Deathes Caster, Qui-Gon Jinn, Yoda Dum?
#
# Later on, he altered his memory to match what his Lord (the Bride of Death), who did not believe him, wanted. Shortly thereafter, he became obsessed with manipulating his memories to enhance his own weapons of combat by turning them into slingshots and other instruments to unleash a Kryptonite storm on a target. He recovered this ability in the process of using it on Meev and Parvati jokingly saying they still loved her.
#
# In an unusual moment for a Jedi Master, he uploaded his entire 'ḳšɾa KochdŽ over Skype to Twitter... where he possessed - one day trapped into written notebooks saying:
#
# Sorry through all that. I tried this twice unto death, not once to actually kill you. I meet people around the world sick of talking about the perks and horrors of death. If I had literally rendered my mind useless it would be impossible for me to each fight someone else's President at the end... The only thing anybody who believes my beliefs to actually happen
# ================================================================================
# Model prompt >>> "It was a difficult game, but the performance was weak," Real Madrid boss Santi Solari on the
# ======================================== SAMPLE 1 ========================================
#  opening night of the season. "It was about character, character - not putting so much energy into it."
#
# Real Madrid could have taken a magnificent chance in this early game by beating Arsenal 2-2 on Tuesday. They are unbeaten on their last 11 starts of the season and plenty confident of a title challenge in Anderlecht.
#
# Form assumption in Bournemouth following victory
#
# Form Dingford – Leicester Stafford tilt vs 2 influential side
#
# Form and fitness most needed for Real Madrid to progress this season
#
# Thu 20 Aug 2016
#
# TGO La Liga lead 10 for the first time in this Champions League era
#
# Tue 15 Aug 2016
#
# TGO Challenge: England vs France - Scott Morgan on a setpiece
#
# Real Madrid's 2-1 defeat at Celtic means goodbye to Blues, who play away against Spain and host champions Leeds United at Hampden on Saturday. Frank Lampard's men were awarded a Copa del Rey spot as is disqualified for Inferno's transfer tense plasma law Labor Day weekend
#
# Heroic Bournemouth comeback from 12 positions against sieges
#
# 04 Aug 2016
#
# Premier League 18 mins: Saints take a crucial 2-1 win at Villa Park, Francois DF replacement of Agita Soares Eric Gryba at left-back but Virgil van Dijk goals with corner gives Southampton a pass
#
# 10 mins: 1-0 United boss playing Pflugner - 74,000 eyes can land a glimpse of the big boys next summer Will substitute with Vardy - Tiago Barzagli has his day in court Allan Wills invites referee banning Spira - mid-flight Set to make his first start of the year with gratitude for Lloyd Sam announce demotion One Brazilian captain comes home to rejoin Luis Suárez
#
# 02 Aug 2016
#
# Stamford vs Sunderland – home to 90 second Sunderland striker used stricken Bournemouth goalie gently puffing living queen
#
# 02 Aug 2016
#
# FA Cup betting-funded three Ref issues Manchester United vs Sunderland
#
# 23 Aug 2016<|endoftext|>Return to News Page<|endoftext|>Chelys Tampa Platformer FoundSperry January 26, 2017 8:59 am
#
# I already know, it's been something of a wreck. I met Yladurta at the organization, and they were all awesome employees all through training. She should let me know what her planned BLB SV Wasteland Model could be without saying chunks, but damn! That kind of information that a PR could pull off on someone just
# ================================================================================
# Model prompt >>> Traceback (most recent call last):
#   File "/usr/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 5253, in get_controller
#     yield g
#   File "src/interactive_conditional_samples.py", line 51, in interact_model
#     raw_text = input("Model prompt >>> ")
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "src/interactive_conditional_samples.py", line 69, in <module>
#     fire.Fire(interact_model)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 127, in Fire
#     component_trace = _Fire(component, args, context, name)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 366, in _Fire
#     component, remaining_args)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 542, in _CallCallable
#     result = fn(*varargs, **kwargs)
#   File "src/interactive_conditional_samples.py", line 66, in interact_model
#     print("=" * 80)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1592, in __exit__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 728, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt
