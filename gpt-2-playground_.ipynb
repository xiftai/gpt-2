# %% [markdown]
# <a href="https://colab.research.google.com/github/ilopezfr/gpt-2/blob/master/gpt-2-playground_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## GPT-2 Playground
#
# This is a Jupyter notebook to play around with OpenAI's GPT-2 Model from the paper "Language Models are Unsupervised Multitask Learners".
#
# *Note: Recommended to set Runtime Type to GPU before running any cell*

# %%
# !git clone https://github.com/ilopezfr/gpt-2/
import os
os.chdir('gpt-2')
# !sh download_model.sh 117M
# !pip3 install -r requirements.txt

# %% [markdown]
# ## Unconditional sample generation
#
# WARNING: Samples are unfiltered and may contain offensive content.
#
# To generate unconditional samples from the small model. There are a few flags available.
# - nsamples: specify the number of samples you want to pring
# - length
# - temperature
# - top_k

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=40 --temperature=0.7 | tee samples
# Out:
# 2019-02-15 18:14:05.089139: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-02-15 18:14:05.089458: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3301860 executing computations on platform Host. Devices:
# 2019-02-15 18:14:05.089509: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-15 18:14:05.184644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-15 18:14:05.185223: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3301440 executing computations on platform CUDA. Devices:
# 2019-02-15 18:14:05.185277: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# ...

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=40
# Out:
# 2019-02-15 18:15:37.465901: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-02-15 18:15:37.466173: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1d4c680 executing computations on platform Host. Devices:
# 2019-02-15 18:15:37.466241: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-15 18:15:37.562713: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-15 18:15:37.563332: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1d4d5a0 executing computations on platform CUDA. Devices:
# 2019-02-15 18:15:37.563366: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# ...

# %% [markdown]
# ## Conditional sample generation
# To give the model custom prompts, you can use:
